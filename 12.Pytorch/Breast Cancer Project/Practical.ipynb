# %%
import numpy as np
import pandas as pd
import torch
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler, LabelEncoder

# %%
df = pd.read_csv('breast-cancer.csv')
df.head()
# Out:
#          id diagnosis  ...  symmetry_worst  fractal_dimension_worst
# 0    842302         M  ...          0.4601                  0.11890
# 1    842517         M  ...          0.2750                  0.08902
# 2  84300903         M  ...          0.3613                  0.08758
# 3  84348301         M  ...          0.6638                  0.17300
# 4  84358402         M  ...          0.2364                  0.07678
#
# [5 rows x 32 columns]

# %%
df.drop(columns=["id"], inplace=True)

# %%
df.head()
# Out:
#   diagnosis  radius_mean  ...  symmetry_worst  fractal_dimension_worst
# 0         M        17.99  ...          0.4601                  0.11890
# 1         M        20.57  ...          0.2750                  0.08902
# 2         M        19.69  ...          0.3613                  0.08758
# 3         M        11.42  ...          0.6638                  0.17300
# 4         M        20.29  ...          0.2364                  0.07678
#
# [5 rows x 31 columns]

# %% [markdown]
# # Train Test Split

# %%
X_train, X_test, y_train, y_test = train_test_split(df.iloc[:, 1:], df.iloc[:, 0], test_size=0.2)

# %% [markdown]
# # Feature Scaling

# %%
scaler = StandardScaler()
X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)

# %% [markdown]
# # Label Encoding

# %%
encoder = LabelEncoder()
y_train = encoder.fit_transform(y_train)
y_test = encoder.transform(y_test)

# %% [markdown]
# # Numpy Arrays to Pytorch tensors

# %%
X_train_tensor = torch.from_numpy(X_train)
X_test_tensor = torch.from_numpy(X_test)
y_train_tensor = torch.from_numpy(y_train)
y_test_tensor = torch.from_numpy(y_test)

# %%
X_train_tensor.shape
# Out:
# torch.Size([455, 30])

# %% [markdown]
# # Defining Model

# %%
class MyFirstNN():
  def __init__(self, X):
    self.weights = torch.rand(X.shape[1], 1, dtype=torch.float64, requires_grad=True)
    self.bias = torch.zeros(1, dtype=torch.float64, requires_grad=True)

  def forward(self, X):
    z = torch.matmul(X, self.weights) + self.bias
    y_pred = torch.sigmoid(z)
    return y_pred

  def loss_function(self, y_pred, y):
    epsilon = 1e-15
    y_pred = torch.clamp(y_pred, epsilon, 1-epsilon)

    loss = -(y_train_tensor * torch.log(y_pred) + (1-y_train_tensor) * torch.log(1-y_pred)).mean()
    return loss

# %% [markdown]
# # Parameters

# %%
learning_rate = 0.1
epochs = 100

# %% [markdown]
# ## Training Pipeline

# %%
# Create Model
model = MyFirstNN(X_train_tensor)

# Define loop
for epoch in range(epochs):
  # Forward pass
  y_pred = model.forward(X_train_tensor)

  # Loss calculation
  loss = model.loss_function(y_pred, y_train_tensor)

  # Backward pass
  loss.backward()

  # Parameter update
  with torch.no_grad():
    model.weights -= learning_rate * model.weights.grad
    model.bias -= learning_rate * model.bias.grad

  # Zero gradients
  model.weights.grad.zero_()
  model.bias.grad.zero_()

  print(f"Epoch: {epoch + 1}, Loss: {loss.item()}")
# Out:
# Epoch: 1, Loss: 3.7409158314267987
# Epoch: 2, Loss: 3.5354561930309796
# Epoch: 3, Loss: 3.326802667463053
# Epoch: 4, Loss: 3.120052030663139
# Epoch: 5, Loss: 2.9154927836338684
# Epoch: 6, Loss: 2.7136096385703903
# Epoch: 7, Loss: 2.5150160356053686
# Epoch: 8, Loss: 2.3205023664862745
# Epoch: 9, Loss: 2.131080074090886
# Epoch: 10, Loss: 1.9480250796680996
# Epoch: 11, Loss: 1.7729020297757052
# Epoch: 12, Loss: 1.6075449289531314
# Epoch: 13, Loss: 1.4539738643507794
# Epoch: 14, Loss: 1.3142540487889571
# Epoch: 15, Loss: 1.190317688986348
# Epoch: 16, Loss: 1.0837324877297276
# Epoch: 17, Loss: 0.9953960504052177
# Epoch: 18, Loss: 0.9251852275504108
# Epoch: 19, Loss: 0.8716583676655197
# Epoch: 20, Loss: 0.832129740251896
# Epoch: 21, Loss: 0.8033739103500237
# Epoch: 22, Loss: 0.7824359863219714
# Epoch: 23, Loss: 0.7669901307474414
# Epoch: 24, Loss: 0.7553458249085556
# Epoch: 25, Loss: 0.7463325044681355
# Epoch: 26, Loss: 0.7391638814686665
# ...

# %% [markdown]
# # Evaluation

# %%
with torch.no_grad():
  y_pred = model.forward(X_test_tensor)
  y_pred = (y_pred > 0.5).float()

  accuracy = (y_pred == y_test_tensor).float().mean()
  print(f"Accuracy: {accuracy.item()}")
# Out:
# Accuracy: 0.5590950846672058

# %% [markdown]
# # Training pipeline using nn module

# %%
import torch
import torch.nn as nn
import torch.optim as optim

# %%
# Ensure tensors are float32 (nn.Module uses float32 by default) and reshape labels to [batch_size, 1] to match the output of the network
X_train_f32 = X_train_tensor.float()
y_train_f32 = y_train_tensor.float().view(-1, 1)
X_test_f32 = X_test_tensor.float()
y_test_f32 = y_test_tensor.float().view(-1, 1)

# %%
# Define Model using nn.Module
class MyFirstNN(nn.Module):
    def __init__(self, num_features):
        super().__init__() # Must call the parent class __init__
        # nn.Linear automatically handles the weights and biases
        self.linear = nn.Linear(num_features, 1)
        self.sigmoid = nn.Sigmoid()

    def forward(self, x):
        out = self.linear(x)
        out = self.sigmoid(out)
        return out

# %%
# Setup Model, Loss, and Optimizer
learning_rate = 0.1
epochs = 100

model = MyFirstNN(num_features=X_train_f32.shape[1])

# PyTorch's built-in Binary Cross Entropy Loss replaces the manual loss_function
criterion = nn.BCELoss()

# The optimizer handles parameter updates automatically
optimizer = optim.SGD(model.parameters(), lr=learning_rate)

# %%
# Training Loop
for epoch in range(epochs):
    # Forward pass
    y_pred = model(X_train_f32)

    # Loss calculation
    loss = criterion(y_pred, y_train_f32)

    # Zero gradients BEFORE the backward pass
    optimizer.zero_grad()

    # Backward pass (compute gradients)
    loss.backward()

    # Parameter update (applies gradients to weights/biases)
    optimizer.step()

    if (epoch + 1) % 10 == 0 or epoch == 0:
        print(f"Epoch: {epoch + 1}, Loss: {loss.item():.4f}")
# Out:
# Epoch: 1, Loss: 0.7380
# Epoch: 10, Loss: 0.2605
# Epoch: 20, Loss: 0.1929
# Epoch: 30, Loss: 0.1638
# Epoch: 40, Loss: 0.1468
# Epoch: 50, Loss: 0.1354
# Epoch: 60, Loss: 0.1271
# Epoch: 70, Loss: 0.1207
# Epoch: 80, Loss: 0.1156
# Epoch: 90, Loss: 0.1114
# Epoch: 100, Loss: 0.1078

# %%
# Evaluation
with torch.no_grad():
    model.eval()

    y_test_pred = model(X_test_f32)
    y_test_pred_class = (y_test_pred > 0.5).float()

    accuracy = (y_test_pred_class == y_test_f32).float().mean()
    print(f"\nAccuracy: {accuracy.item():.4f}")
# Out:
# Accuracy: 0.9737
